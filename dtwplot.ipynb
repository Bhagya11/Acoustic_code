# %%
from obspy.core import read
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-5d51a8c5a345> in <module>()
# ----> 1 from obspy.core import read
#
# ModuleNotFoundError: No module named 'obspy'

# %%
# !pip install obspy
# Out:
# ...
#      ---------------------------------------- 14.0/14.0 MB 3.4 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 7.2/7.2 MB 3.7 MB/s eta 0:00:00
# ...
#   Using cached packaging-21.3-py3-none-any.whl (40 kB)
# ...
#      -------------------------------------- 960.8/960.8 kB 3.0 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 3.3/3.3 MB 3.2 MB/s eta 0:00:00
# ...
#   Using cached pyparsing-3.0.9-py3-none-any.whl (98 kB)
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 2.2.0
#     Uninstalling pyparsing-2.2.0:
#       Successfully uninstalled pyparsing-2.2.0
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 5.2.0
#     Uninstalling Pillow-5.2.0:
#       Successfully uninstalled Pillow-5.2.0
# WARNING: Ignoring invalid distribution -andas (c:\users\polav\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\users\polav\anaconda3\lib\site-packages)
# ...

# %%
python.exe -m pip install --upgrade pip
# Out:
#   File "<ipython-input-4-ff5498119d48>", line 1
#     python.exe -m pip install --upgrade pip
#                     ^
# SyntaxError: invalid syntax

# %%
from scipy.io.wavfile import read
import matplotlib.pyplot as plt

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(r'C:\Users\polav\Desktop\sample.csv')

# %%
data
# Out:
#         time        i           e          ae            a        aw  \
# 0   0.108944  338.015  581.573000  754.077000   963.317235  693.5730
# 1   0.108944  339.966  585.420000  786.822000  1001.473000  685.7320
# 2   0.108944  339.924  586.610000  830.472000  1006.784667  678.5680
# 3   0.108944  342.956  586.334000  858.731000  1011.809000  678.9790
# 4   0.108944  345.437  586.447000  858.731000  1016.165000  682.4600
# 5   0.108944  345.337  586.305000  858.731000  1016.165000  682.4600
# 6   0.108944  343.813  581.810000  869.562000  1016.165000  682.4600
# 7   0.108944  342.523  582.362000  883.127000  1016.165000  682.4600
# 8   0.108944  340.425  583.094000  883.127000  1016.165000  682.4600
# 9   0.108944  338.046  582.018000  883.127000  1016.165000  689.2450
# 10  0.108944  338.639  584.548000  883.127000  1016.165000  689.2450
# 11  0.108944  336.842  585.058000  883.127000  1016.165000  689.2450
# 12  0.108944  335.118  585.059000  883.127000  1016.165000  694.6890
# ...

# %%
#Filling null valyes with 0
dtwdata = data.replace('nan', np.nan).fillna(0)

# %%
dtwdata
# Out:
#         time        i           e          ae            a        aw  \
# 0   0.108944  338.015  581.573000  754.077000   963.317235  693.5730
# 1   0.108944  339.966  585.420000  786.822000  1001.473000  685.7320
# 2   0.108944  339.924  586.610000  830.472000  1006.784667  678.5680
# 3   0.108944  342.956  586.334000  858.731000  1011.809000  678.9790
# 4   0.108944  345.437  586.447000  858.731000  1016.165000  682.4600
# 5   0.108944  345.337  586.305000  858.731000  1016.165000  682.4600
# 6   0.108944  343.813  581.810000  869.562000  1016.165000  682.4600
# 7   0.108944  342.523  582.362000  883.127000  1016.165000  682.4600
# 8   0.108944  340.425  583.094000  883.127000  1016.165000  682.4600
# 9   0.108944  338.046  582.018000  883.127000  1016.165000  689.2450
# 10  0.108944  338.639  584.548000  883.127000  1016.165000  689.2450
# 11  0.108944  336.842  585.058000  883.127000  1016.165000  689.2450
# 12  0.108944  335.118  585.059000  883.127000  1016.165000  694.6890
# ...

# %%
dtwdata.columns[0]
# Out:
# 'time'

# %%
plt.plot(dtwdata['time'],dtwdata[dtwdata.columns[1]])
plt.plot(dtwdata['time'],dtwdata[dtwdata.columns[2]])
plt.plot(dtwdata['time'],dtwdata[dtwdata.columns[3]])
plt.plot(dtwdata['time'],dtwdata[dtwdata.columns[4]])
# Out:
# C:\Users\polav\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:2064: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# C:\Users\polav\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:248: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# C:\Users\polav\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:250: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %%
data=pd.read_csv(r'C:\Users\polav\Desktop\Acoustic code\DTW\dtws\iua\iua1.csv')

# %%
data
# Out:
#         if1       if2          if3         uf1         uf2       uf3  \
# 0   338.015  2973.213  3525.927000  412.025000  808.035000  2907.535
# 1   339.966  2974.616  3517.364000  401.124000  808.035000  2904.261
# 2   339.924  2976.345  3528.440000  420.832538  808.035000  2930.273
# 3   342.956  2972.642  3486.808000  390.497000  808.035000  2930.273
# 4   345.437  2971.929  3486.808000  390.497000  808.035000  2930.273
# 5   345.337  2985.516  3486.808000  383.060000  808.035000  2930.273
# 6   343.813  2975.203  3500.987500  375.009000  808.035000  2930.273
# 7   342.523  2964.651  3476.143000  364.151000  806.808231  2930.273
# 8   340.425  2952.170  3426.726267  364.151000  811.033000  2930.273
# 9   338.046  2948.965  3348.083000  364.151000  811.319000  2930.273
# 10  338.639  2920.051  3348.083000  364.151000  811.246000  2930.273
# 11  336.842  2894.592  3348.083000  364.151000  810.610000  2930.273
# 12  335.118  2894.592  3348.083000  364.151000  808.812000  2930.273
# ...

# %%
#Filling null valyes with 0
dtwdata = data.replace('nan', np.nan).fillna(0)

# %%
dtwdata
# Out:
#         if1       if2          if3         uf1         uf2       uf3  \
# 0   338.015  2973.213  3525.927000  412.025000  808.035000  2907.535
# 1   339.966  2974.616  3517.364000  401.124000  808.035000  2904.261
# 2   339.924  2976.345  3528.440000  420.832538  808.035000  2930.273
# 3   342.956  2972.642  3486.808000  390.497000  808.035000  2930.273
# 4   345.437  2971.929  3486.808000  390.497000  808.035000  2930.273
# 5   345.337  2985.516  3486.808000  383.060000  808.035000  2930.273
# 6   343.813  2975.203  3500.987500  375.009000  808.035000  2930.273
# 7   342.523  2964.651  3476.143000  364.151000  806.808231  2930.273
# 8   340.425  2952.170  3426.726267  364.151000  811.033000  2930.273
# 9   338.046  2948.965  3348.083000  364.151000  811.319000  2930.273
# 10  338.639  2920.051  3348.083000  364.151000  811.246000  2930.273
# 11  336.842  2894.592  3348.083000  364.151000  810.610000  2930.273
# 12  335.118  2894.592  3348.083000  364.151000  808.812000  2930.273
# ...

# %%
plt.plot(dtwdata['if1'])
plt.plot(dtwdata['if2'])
plt.plot(dtwdata['if3'])

# %%
plt.plot(dtwdata['af1'])
plt.plot(dtwdata['af2'])
plt.plot(dtwdata['af3'])

# %%
plt.plot(dtwdata['uf1'])
plt.plot(dtwdata['uf2'])
plt.plot(dtwdata['uf3'])
